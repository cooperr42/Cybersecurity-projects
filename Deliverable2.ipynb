# %% [markdown]
# ## 1. Imports & Helper Function

# %%
import json
import pandas as pd
from typing import Tuple

def process_nvd_json(file_path: str) -> Tuple[pd.DataFrame, pd.DataFrame]:
    with open(file_path, 'r', encoding='ISO-8859-1') as f:
        nvd_data = json.load(f)

    cve_items = []
    cpe_items = []
    for item in nvd_data['CVE_Items']:
        meta = item['cve']['CVE_data_meta']
        cve_id = meta['ID']
        descs = item['cve']['description']['description_data']

        prob = item['cve']['problemtype']['problemtype_data']
        try:
            cwe = prob[0]['description'][0]['value']
        except:
            cwe = ''

        impact3 = item.get('impact', {}) \
                      .get('baseMetricV3', {}) \
                      .get('cvssV3', {})
        cve_items.append({
            'id': cve_id,
            'assigner': meta.get('ASSIGNER',''),
            'published_date': item.get('publishedDate'),
            'last_modified_date': item.get('lastModifiedDate'),
            'description': next((d['value'] for d in descs if d['lang']=='en'), ''),
            'cwe': cwe,
            'cvss3_vector': impact3.get('vectorString',''),
            'cvss3_base_score': impact3.get('baseScore', None),
            'cvss3_base_severity': impact3.get('baseSeverity','')
        })

        for node in item['configurations'].get('nodes', []):
            for cm in node.get('cpe_match', []):
                uri = cm.get('cpe23Uri','')
                parts = uri.split(':')
                cpe_items.append({
                    'cve_id': cve_id,
                    'cpe23Uri': uri,
                    'vulnerable': cm.get('vulnerable', False),
                    'versionStartIncluding': cm.get('versionStartIncluding',''),
                    'versionEndIncluding': cm.get('versionEndIncluding',''),
                    'vendor': parts[3] if len(parts)>3 else '',
                    'product': parts[4] if len(parts)>4 else '',
                    'version': parts[5] if len(parts)>5 else ''
                })

cve_df = pd.DataFrame(cve_items)
 cpe_df = pd.DataFrame(cpe_items)
    for col in ['published_date','last_modified_date']:
        cve_df[col] = pd.to_datetime(cve_df[col], errors='coerce')
    cve_df.sort_values('id', inplace=True)
    cpe_df.sort_values(['cve_id','cpe23Uri'], inplace=True)
    return cve_df, cpe_df
# Out:
# Error: File 'Project/nvdcve-1.1-2024.json' not found.

# %% [markdown]
# ## 2. Load & Process NVD JSON (2023)

# %%
nvd_file = 'nvdcve-1.1-2024.json'
cve_df, cpe_df = process_nvd_json(nvd_file)
cve_df.info()
cve_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37730 entries, 0 to 37729
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   37730 non-null  object
#  1   assigner             37730 non-null  object
#  2   published_date       37730 non-null  datetime64[ns, UTC]
#  3   last_modified_date   37730 non-null  datetime64[ns, UTC]
#  4   description          37730 non-null  object
#  5   cwe                  37730 non-null  object
#  6   cvss3_vector         37730 non-null  object
#  7   cvss3_base_score     20271 non-null  float64
#  8   cvss3_base_severity  37730 non-null  object
# dtypes: datetime64[ns, UTC](2), float64(1), object(6)
# memory usage: 2.6+ MB
#               id               assigner            published_date  \
# 0  CVE-2024-0001  psirt@purestorage.com 2024-09-23 18:15:00+00:00
# 1  CVE-2024-0002  psirt@purestorage.com 2024-09-23 18:15:00+00:00
# 2  CVE-2024-0003  psirt@purestorage.com 2024-09-23 18:15:00+00:00
# 3  CVE-2024-0004  psirt@purestorage.com 2024-09-23 18:15:00+00:00
# 4  CVE-2024-0005  psirt@purestorage.com 2024-09-23 18:15:00+00:00
#
#          last_modified_date  \
# 0 2024-09-27 14:08:00+00:00
# 1 2024-09-27 14:13:00+00:00
# 2 2024-09-27 14:23:00+00:00
# 3 2024-09-27 14:24:00+00:00
# 4 2024-09-27 15:25:00+00:00
#
#                                          description             cwe  \
# 0  A condition exists in FlashArray Purity whereb...        CWE-1188
# 1  A condition exists in FlashArray Purity whereb...  NVD-CWE-noinfo
# 2  A condition exists in FlashArray Purity whereb...  NVD-CWE-noinfo
# 3  A condition exists in FlashArray Purity whereb...          CWE-94
# 4  A condition exists in FlashArray and FlashBlad...          CWE-77
#
#                                    cvss3_vector  cvss3_base_score  \
# 0  CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               9.8
# 1  CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               9.8
# 2  CVSS:3.1/AV:N/AC:L/PR:H/UI:N/S:U/C:H/I:H/A:H               7.2
# 3  CVSS:3.1/AV:N/AC:L/PR:H/UI:N/S:U/C:H/I:H/A:H               7.2
# 4  CVSS:3.1/AV:N/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H               8.8
#
#   cvss3_base_severity
# 0            CRITICAL
# 1            CRITICAL
# 2                HIGH
# 3                HIGH
# 4                HIGH

# %% [markdown]
# ## 3. Load KEV Catalog

# %%
kev_file = 'known_exploited_vulnerabilities.csv'
df_kev = pd.read_csv(kev_file)
df_kev.rename(columns={'cveID':'id','dateAdded':'kev_added_date'}, inplace=True)
df_kev['kev_added_date'] = pd.to_datetime(df_kev['kev_added_date'], errors='coerce')
df_kev.info()
df_kev.head()
# Out:
# === KEV DataFrame ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1323 entries, 0 to 1322
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          1323 non-null   object
#  1   vendorProject               1323 non-null   object
#  2   product                     1323 non-null   object
#  3   vulnerabilityName           1323 non-null   object
#  4   kev_added_date              1323 non-null   datetime64[ns]
#  5   shortDescription            1323 non-null   object
#  6   requiredAction              1323 non-null   object
#  7   dueDate                     1323 non-null   object
#  8   knownRansomwareCampaignUse  1323 non-null   object
#  9   notes                       1323 non-null   object
#  10  cwes                        1177 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 113.8+ KB
#                id vendorProject            product  \
# 0  CVE-2025-24054     Microsoft            Windows
# 1  CVE-2025-31201         Apple  Multiple Products
# 2  CVE-2025-31200         Apple  Multiple Products
# 3  CVE-2021-20035     SonicWall  SMA100 Appliances
# 4  CVE-2024-53150         Linux             Kernel
#
#                                    vulnerabilityName kev_added_date  \
# 0  Microsoft Windows NTLM Hash Disclosure Spoofin...     2025-04-17
# 1  Apple Multiple Products Arbitrary Read and Wri...     2025-04-17
# 2  Apple Multiple Products Memory Corruption Vuln...     2025-04-17
# 3  SonicWall SMA100 Appliances OS Command Injecti...     2025-04-16
# 4      Linux Kernel Out-of-Bounds Read Vulnerability     2025-04-09
#
#                                     shortDescription  \
# 0  Microsoft Windows NTLM contains an external co...
# 1  Apple iOS, iPadOS, macOS, and other Apple prod...
# 2  Apple iOS, iPadOS, macOS, and other Apple prod...
# 3  SonicWall SMA100 appliances contain an OS comm...
# 4  Linux Kernel contains an out-of-bounds read vu...
#
#                                       requiredAction     dueDate  \
# 0  Apply mitigations per vendor instructions, fol...  2025-05-08
# 1  Apply mitigations per vendor instructions, fol...  2025-05-08
# 2  Apply mitigations per vendor instructions, fol...  2025-05-08
# 3  Apply mitigations per vendor instructions, fol...  2025-05-07
# 4  Apply mitigations per vendor instructions, fol...  2025-04-30
#
#   knownRansomwareCampaignUse  \
# 0                    Unknown
# 1                    Unknown
# 2                    Unknown
# 3                    Unknown
# 4                    Unknown
#
#                                                notes     cwes
# 0  https://msrc.microsoft.com/update-guide/vulner...   CWE-73
# 1  https://support.apple.com/en-us/122282 ; https...      NaN
# 2  https://support.apple.com/en-us/122282 ; https...      NaN
# 3  https://psirt.global.sonicwall.com/vuln-detail...   CWE-78
# 4  This vulnerability affects a common open-sourc...  CWE-125

# %% [markdown]
# ## 4. Merge & Flag Exploited

# %%
df_merged = cve_df.merge(df_kev[['id','kev_added_date']], on='id', how='left')
df_merged['is_exploited'] = df_merged['kev_added_date'].notna()
df_merged.info()
print("\nFirst 5 rows:")
df_merged.head()
print("\nExploited counts:")
df_merged['is_exploited'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37730 entries, 0 to 37729
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   37730 non-null  object
#  1   assigner             37730 non-null  object
#  2   published_date       37730 non-null  datetime64[ns, UTC]
#  3   last_modified_date   37730 non-null  datetime64[ns, UTC]
#  4   description          37730 non-null  object
#  5   cwe                  37730 non-null  object
#  6   cvss3_vector         37730 non-null  object
#  7   cvss3_base_score     20271 non-null  float64
#  8   cvss3_base_severity  37730 non-null  object
#  9   kev_added_date       142 non-null    datetime64[ns]
#  10  is_exploited         37730 non-null  bool
# dtypes: bool(1), datetime64[ns, UTC](2), datetime64[ns](1), float64(1), object(6)
# memory usage: 2.9+ MB
#
# First 5 rows:
#
# Exploited counts:
# is_exploited
# False    37588
# True       142
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Save Final Table

# %%
out_csv = 'nvd_plus_kev_2024.csv'
df_merged.to_csv(out_csv, index=False)
print(f"Saved merged table to {out_csv}")
# Out:
# Saved merged table to nvd_plus_kev_2024.csv
